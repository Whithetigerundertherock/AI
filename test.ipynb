# %%
import numpy as np
import pandas as pd

# %%
# !pip install yfinance

# %%
import yfinance as yf
df = yf.download('005930.KS','2024-01-01','2024-08-23')
df.to_excel("삼성전자.xlsx")
df.to_csv("삼성전자.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2024-01-02  78200.0  79800.0  78200.0  79600.0  78888.054688  17142847
# 2024-01-03  78500.0  78800.0  77000.0  77000.0  76311.304688  21753644
# 2024-01-04  76100.0  77300.0  76100.0  76600.0  75914.882812  15324439
# 2024-01-05  76700.0  77100.0  76400.0  76600.0  75914.882812  11304316
# 2024-01-08  77000.0  77500.0  76400.0  76500.0  75815.781250  11088724
# ...             ...      ...      ...      ...           ...       ...
# 2024-08-16  79400.0  80200.0  78700.0  80200.0  80200.000000  22061478
# 2024-08-19  80100.0  80100.0  78000.0  78300.0  78300.000000  14146565
# 2024-08-20  79500.0  79800.0  78700.0  78900.0  78900.000000  10683836
# 2024-08-21  77900.0  78600.0  77800.0  78300.0  78300.000000   7805598
# 2024-08-22  78700.0  78900.0  77800.0  78300.0  78300.000000   8149101
#
# [159 rows x 6 columns]
